# %%
# !pip install -U transformers

# %% [markdown]
# ## Inferência Local em GPU
# Página do modelo: https://huggingface.co/Raggio/dondza-xitsonga-asr-wav2vec2
#
# ⚠️ Se os fragmentos de código gerados não funcionarem, por favor abra um issue no [repositório do modelo](https://huggingface.co/Raggio/dondza-xitsonga-asr-wav2vec2)
# 			e/ou no [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Usar um pipeline como auxiliar de alto nível
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", model="Raggio/dondza-xitsonga-asr-wav2vec2")

# %%
# Carregar modelo directamente
from transformers import AutoProcessor, AutoModelForCTC

processor = AutoProcessor.from_pretrained("Raggio/dondza-xitsonga-asr-wav2vec2")
model = AutoModelForCTC.from_pretrained("Raggio/dondza-xitsonga-asr-wav2vec2")
